# %%
# %run "../SDFC/__TransitionsMCMC.py"

# %% [markdown]
# # Test Transitions Fuctions
# ## Fixed

# %%
x=np.array([0,0,0,0,0])
tran_scale_G=np.array([5])
transition_fixed(x,tran_scale_G)
# Out:
# array([-2.46562417, -1.85267824,  0.06693451,  3.73975874,  1.71167929])

# %%
tran_scale_G=np.array([1,2,3,4,5])
transition_fixed(x,tran_scale_G)
# Out:
# array([ 0.73334895,  2.06269286,  1.6057081 , -0.40651648, -2.53161441])

# %% [markdown]
# ## MH Adaptative

# %%
draw=np.array([[0,0,0,0,0],[1,2,3,4,5],[5,4,3,2,1],[1,0,2,5,6],[5,5,4,7,0]])

i=1
transition_adaptative(x,i,draw,init=0.01,epsilon=0.01)
# Out:
# array([-0.09479239,  0.00147152, -0.0179315 ,  0.02974501,  0.07574296])

# %%
i=500
transition_adaptative(x,i,draw,init=0.01,epsilon=0.01)
# Out:
# array([-1.29753391, -0.88755295,  0.35645087,  2.262769  ,  2.4707717 ])

# %%
i=1000
transition_adaptative(x,i,draw,init=0.01,epsilon=0.01)
# Out:
# array([-1.98701774, -2.62447525, -3.52061578, -7.01209002, -4.11342379])

# %%
## MH-WG Adaptative

# %% [markdown]
# ## Testing on full algorithm
# Only with GEV
# ### MH

# %%
import SDFC as sd

# %%
import numpy as np
import scipy.stats as sc

# %%
n_samples=1000
n_mcmc_drawn=1000
prior_law=sc.multivariate_normal( mean = [2,1,-0.1] , cov = np.identity(3)*(0.1) , allow_singular = True )

# %%
kwargs = { "n_samples" : n_samples ,
"name"    : "GEV" ,
"sd_law"  : sd.GEV() ,
"params"  : ["loc","scale","shape"] ,
"shape_p" : False}

# %%
#Ok run. Fixed, one scale
kwargs["transition_type"]="Fixed"
kwargs["fixed_cov"]=np.array([0.5])
ns_law=sd.GEV()
Yo     = sc.genextreme( loc = 2 ,  scale =0.5 , c = - 0.1 ).rvs(150)
ns_law._method="bayesian"
ns_law.fit( Yo , n_mcmc_drawn =  n_mcmc_drawn , prior=prior_law , **kwargs )
ns_law.loc
# Out:
# array([2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772,
#        2.10339772, 2.10339772, 2.10339772, 2.10339772, 2.10339772])

# %%
#Ok run. Fixed, dif scale
kwargs["transition_type"]="Fixed"
kwargs["fixed_cov"]=np.array([0.5,0.1,0.2])
ns_law=sd.GEV()
Yo     = sc.genextreme( loc = 2 ,  scale =0.5 , c = - 0.1 ).rvs(150)
ns_law._method="bayesian"
ns_law.fit( Yo , n_mcmc_drawn =  n_mcmc_drawn , prior=prior_law , **kwargs )
ns_law.loc
# Out:
# array([2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445,
#        2.13442445, 2.13442445, 2.13442445, 2.13442445, 2.13442445])

# %%
#Ok run. adaptative
kwargs["transition_type"]="Adapt"

ns_law=sd.GEV()
Yo     = sc.genextreme( loc = 2 ,  scale =0.5 , c = - 0.1 ).rvs(150)
ns_law._method="bayesian"
ns_law.fit( Yo , n_mcmc_drawn =  n_mcmc_drawn , prior=prior_law , **kwargs )
ns_law.loc
# Out:
# /home/barbauxo/Documents/05_Autres Activités/2023_11_Transfert_Code_Yoann/SDFC-python/SDFC/__AbstractLaw.py:326: RuntimeWarning: invalid value encountered in scalar subtract
#   p_accept = np.exp( p_next - p_current )
# array([2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334,
#        2.38932334, 2.38932334, 2.38932334, 2.38932334, 2.38932334])

# %% [markdown]
# # Test MH-WG

# %%
import SDFC as sd
import numpy as np
import scipy.stats as sc

# %%
n_samples=1000
n_mcmc_drawn=1000
prior_law=sc.multivariate_normal( mean = [2,1,-0.1] , cov = np.identity(3)*(0.1) , allow_singular = True )
kwargs = { "n_samples" : n_samples ,
"name"    : "GEV" ,
"sd_law"  : sd.GEV() ,
"params"  : ["loc","scale","shape"] ,
"shape_p" : False}

# %%
#Ok run. Fixed, all scales 
kwargs["transition_type"]="Fixed"
kwargs["fixed_cov"]=np.array([0.5,0.2,0.3])
ns_law=sd.GEV()
Yo     = sc.genextreme( loc = 2 ,  scale =0.5 , c = - 0.1 ).rvs(150)
ns_law._method="bayesian-experimental-mhwg"
ns_law.fit( Yo , n_mcmc_drawn =  n_mcmc_drawn , prior=prior_law , **kwargs )
ns_law.loc
# Out:
# array([2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204,
#        2.02436204, 2.02436204, 2.02436204, 2.02436204, 2.02436204])

# %%
ns_law.info_.rate_accept
# Out:
# 0.17766666666666667

# %%
#Ok run. adaptative
kwargs["transition_type"]="Adapt"

ns_law=sd.GEV()
Yo         = sc.genextreme( loc = 2 ,  scale =0.5 , c = - 0.1 ).rvs(150)
ns_law._method="bayesian-experimental-mhwg"
ns_law.fit( Yo , n_mcmc_drawn =  n_mcmc_drawn , prior=prior_law , **kwargs )
ns_law.loc
# Out:
# /home/barbauxo/Documents/05_Autres Activités/2023_11_Transfert_Code_Yoann/SDFC-python/SDFC/__AbstractLaw.py:512: RuntimeWarning: invalid value encountered in scalar subtract
#   p_accept = np.exp( p_next - p_current )
# array([1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952,
#        1.99420952, 1.99420952, 1.99420952, 1.99420952, 1.99420952])

# %%
ns_law.info_.rate_accept
# Out:
# 0.595

# %%
ns_law.info_.draw
# Out:
# array([[ 1.74283238,  1.13758527, -0.30056109],
#        [ 1.74283238,  1.13758527, -0.30056109],
#        [ 1.74283238,  1.13758527, -0.30056109],
#        ...,
#        [ 1.93716532,  0.42863608,  0.34883365],
#        [ 1.93716532,  0.51412616,  0.34883365],
#        [ 1.93716532,  0.4704956 ,  0.29842332]])

# %% [markdown]
# ## MCMC Visual Diagnostics and visuals checks

# %%
ns_law.info_.accept
# Out:
# array([[False, False, False],
#        [ True,  True,  True],
#        [ True,  True,  True],
#        ...,
#        [False, False,  True],
#        [False, False, False],
#        [ True, False, False]])

# %%
ns_law.coef_ #Still work for 5 ?
# Out:
# array([2.01502247, 0.49310487, 0.09406759])

# %%
sd.Summary_run_table(ns_law,prior_law,MLE_theta=["","",""],pathOut="",q_l=0.05,q_h=0.95,show=True)
# Out:
# Total acceptation rate is 0.5513333333333333 for 1000 iterations
# ╒═════════════╤═════════╤═══════╤════════════╤═══════════╤═══════════╤══════════╤══════════════╤════════════════════╕
# │ Paramètre   │   Prior │ MLE   │     Q_0.05 │   Médiane │   Moyenne │   Q_0.95 │   eff sample │   acceptation rate │
# ╞═════════════╪═════════╪═══════╪════════════╪═══════════╪═══════════╪══════════╪══════════════╪════════════════════╡
# │ loc         │     2   │       │  1.66251   │ 1.98131   │ 1.96187   │ 2.1133   │      8.44797 │              0.612 │
# ├─────────────┼─────────┼───────┼────────────┼───────────┼───────────┼──────────┼──────────────┼────────────────────┤
# │ scale       │     1   │       │  0.524071  │ 0.717702  │ 0.911154  │ 1.81935  │      1.29914 │              0.397 │
# ├─────────────┼─────────┼───────┼────────────┼───────────┼───────────┼──────────┼──────────────┼────────────────────┤
# │ shape       │    -0.1 │       │ -0.0710393 │ 0.0151523 │ 0.0523924 │ 0.262841 │      6.97207 │              0.645 │
# ╘═════════════╧═════════╧═══════╧════════════╧═══════════╧═══════════╧══════════╧══════════════╧════════════════════╛

# %%
sd.Para_Runs(ns_law,prior_law,MLE_theta=["","",""],pathOut="",q_l=0.05,q_h=0.95,show=True)

# %% [markdown]
# # ESS stopping point
# No fixed length of the algorithm, stop when enough samples

# %%
import SDFC as sd
import numpy as np
import scipy.stats as sc

# %%
n_samples=1000
n_mcmc_drawn=10000
prior_law=sc.multivariate_normal( mean = [2,1,-0.1] , cov = np.identity(3)*(0.1) , allow_singular = True )
kwargs = { "n_samples" : n_samples ,
"name"    : "GEV" ,
"sd_law"  : sd.GEV() ,
"params"  : ["loc","scale","shape"] ,
"shape_p" : False,
"n_ess"   : 10,
"burn_in" : 800        }

# %%
#Ok run. Fixed, all scales 
kwargs["transition_type"]="Fixed"
kwargs["fixed_cov"]=np.array([0.5,0.2,0.3])
ns_law=sd.GEV()
Yo     = sc.genextreme( loc = 2 ,  scale =0.5 , c = - 0.1 ).rvs(150)
ns_law._method="bayesian-experimental-ess"
ns_law.fit( Yo  , prior=prior_law , **kwargs )
ns_law.loc
# Out:
# array([2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353,
#        2.11784353, 2.11784353, 2.11784353, 2.11784353, 2.11784353])

# %%
ns_law.info_.rate_accept
# Out:
# 0.0

# %%
#Ok run. adaptative
kwargs["transition_type"]="Adapt"

ns_law=sd.GEV()
Yo         = sc.genextreme( loc = 2 ,  scale =0.5 , c = - 0.1 ).rvs(150)
ns_law._method="bayesian-experimental-ess"
ns_law.fit( Yo , prior=prior_law , **kwargs )
ns_law.loc
# Out:
# array([1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088,
#        1.93166088, 1.93166088, 1.93166088, 1.93166088, 1.93166088])

# %%
ns_law.info_.rate_accept
# Out:
# 0.032758620689655175

# %%
sd.Para_Runs(ns_law,prior_law,MLE_theta=["","",""],pathOut="",q_l=0.05,q_h=0.95,show=True)
sd.Summary_run_table(ns_law,prior_law,MLE_theta=["","",""],pathOut="",q_l=0.05,q_h=0.95,show=True)
# Out:
# Total acceptation rate is 0.10555555555555556 for 360 iterations
# ╒═════════════╤═════════╤═══════╤═════════════╤═══════════╤═══════════╤══════════╤══════════════╤════════════════════╕
# │ Paramètre   │   Prior │ MLE   │      Q_0.05 │   Médiane │   Moyenne │   Q_0.95 │   eff sample │   acceptation rate │
# ╞═════════════╪═════════╪═══════╪═════════════╪═══════════╪═══════════╪══════════╪══════════════╪════════════════════╡
# │ loc         │     2   │       │  1.85994    │ 1.93025   │  1.93166  │ 2.00761  │      34.0959 │           0.105556 │
# ├─────────────┼─────────┼───────┼─────────────┼───────────┼───────────┼──────────┼──────────────┼────────────────────┤
# │ scale       │     1   │       │  0.499072   │ 0.544606  │  0.550872 │ 0.594061 │      24.3877 │           0.105556 │
# ├─────────────┼─────────┼───────┼─────────────┼───────────┼───────────┼──────────┼──────────────┼────────────────────┤
# │ shape       │    -0.1 │       │ -0.00364691 │ 0.0855301 │  0.109212 │ 0.23844  │      10.2445 │           0.105556 │
# ╘═════════════╧═════════╧═══════╧═════════════╧═══════════╧═══════════╧══════════╧══════════════╧════════════════════╛

# %%
#Ok run. Fixed, all scales 
kwargs["transition_type"]="Fixed"
kwargs["fixed_cov"]=np.array([0.5,0.2,0.3])
ns_law=sd.GEV()
Yo     = sc.genextreme( loc = 2 ,  scale =0.5 , c = - 0.1 ).rvs(150)
ns_law._method="bayesian-experimental-mhwg-ess"
ns_law.fit( Yo  , prior=prior_law , **kwargs )
ns_law.loc
# Out:
# /home/barbauxo/Documents/05_Autres Activités/2023_11_Transfert_Code_Yoann/SDFC-python/SDFC/__AbstractLaw.py:733: RuntimeWarning: invalid value encountered in scalar subtract
#   p_accept = np.exp( p_next - p_current )
# array([1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407,
#        1.94436407, 1.94436407, 1.94436407, 1.94436407, 1.94436407])

# %%
ns_law.info_.rate_accept
# Out:
# 0.013872832369942197

# %%
#Ok run. adaptative
kwargs["transition_type"]="Adapt"

ns_law=sd.GEV()
Yo         = sc.genextreme( loc = 2 ,  scale =0.5 , c = - 0.1 ).rvs(150)
ns_law._method="bayesian-experimental-mhwg-ess"
ns_law.fit( Yo , prior=prior_law , **kwargs )
ns_law.info_.rate_accept
# Out:
# 0.008954008954008955

# %%
sd.Para_Runs(ns_law,prior_law,MLE_theta=["","",""],pathOut="",q_l=0.05,q_h=0.95,show=True)
sd.Summary_run_table(ns_law,prior_law,MLE_theta=["","",""],pathOut="",q_l=0.05,q_h=0.95,show=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 sd.Para_Runs(ns_law,prior_law,MLE_theta=["","",""],pathOut="",q_l=0.05,q_h=0.95,show=True)
#       2 sd.Summary_run_table(ns_law,prior_law,MLE_theta=["","",""],pathOut="",q_l=0.05,q_h=0.95,show=True)
#
# File ~/Documents/05_Autres Activités/2023_11_Transfert_Code_Yoann/SDFC-python/SDFC/__AddonsMCMC.py:147, in Para_Runs(ns_law, prior_law, MLE_theta, pathOut, q_l, q_h, show)
#     142 #plt.show()
#     143
#     144 #pdf.savefig(fig)
#     145 #plt.close(fig)
#     146 ax = fig.add_subplot( gs[1, :])
# --> 147 plot_acf(draw[:,i],lags=120,ax=ax )
#     148 plt.ylim([-0.1,1.1])
#     149 plt.title("Autocorrelation " +coef[i])
#
# File ~/miniconda3/envs/TestSDFC/lib/python3.12/site-packages/pandas/util/_decorators.py:213, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     211         raise TypeError(msg)
#     212     kwargs[new_arg_name] = new_arg_value
# --> 213 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/TestSDFC/lib/python3.12/site-packages/statsmodels/graphics/tsaplots.py:227, in plot_acf(x, ax, lags, alpha, use_vlines, adjusted, fft, missing, title, zero, auto_ylims, bartlett_confint, vlines_kwargs, **kwargs)
#     224 if alpha is not None:
#     225     acf_x, confint = acf_x[:2]
# --> 227 _plot_corr(
#     228     ax,
#     229     title,
#     230     acf_x,
#     231     confint,
#     232     lags,
#     233     irregular,
#     234     use_vlines,
#     235     vlines_kwargs,
#     236     auto_ylims=auto_ylims,
#     237     **kwargs,
#     238 )
#     240 return fig
#
# File ~/miniconda3/envs/TestSDFC/lib/python3.12/site-packages/statsmodels/graphics/tsaplots.py:49, in _plot_corr(ax, title, acf_x, confint, lags, irregular, use_vlines, vlines_kwargs, auto_ylims, **kwargs)
#      46         confint = confint[lags]
#      48 if use_vlines:
# ---> 49     ax.vlines(lags, [0], acf_x, **vlines_kwargs)
#      50     ax.axhline(**kwargs)
#      52 kwargs.setdefault("marker", "o")
#
# File ~/miniconda3/envs/TestSDFC/lib/python3.12/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/envs/TestSDFC/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1195, in Axes.vlines(self, x, ymin, ymax, colors, linestyles, label, **kwargs)
#    1193 masked_verts[:, 0, 1] = ymin
#    1194 masked_verts[:, 1, 0] = x
# -> 1195 masked_verts[:, 1, 1] = ymax
#    1197 lines = mcoll.LineCollection(masked_verts, colors=colors,
#    1198                              linestyles=linestyles, label=label)
#    1199 self.add_collection(lines, autolim=False)
#
# File ~/miniconda3/envs/TestSDFC/lib/python3.12/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File ~/miniconda3/envs/TestSDFC/lib/python3.12/site-packages/numpy/ma/core.py:3387, in MaskedArray.__setitem__(self, indx, value)
#    3384     mval = tuple([False] * len(_dtype.names))
#    3385 if _mask is nomask:
#    3386     # Set the data, then the mask
# -> 3387     _data[indx] = dval
#    3388     if mval is not nomask:
#    3389         _mask = self._mask = make_mask_none(self.shape, _dtype)
#
# ValueError: could not broadcast input array from shape (19,) into shape (121,)
